# %% [markdown]
# # Crypto Portfolio Optimization

# %% [markdown]
# Goal: Create a machine learning-driven portfolio optimization system for cryptocurrencies, dynamically adjusting allocations to maximize returns and minimize risks based on predictive analytics.

# %% [markdown]
# ### Top crypto cryptocurrencies

# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv

from db import save_df

load_dotenv()
# Out:
# True

# %% [markdown]
# ##### Coingecko API to get the top 20 cryptos

# %%
def fetch_top_coins_tickers(vs_currency='usd', limit=30):
    api_key = os.environ["COINGECKO_API_KEY"]
    url = 'https://api.coingecko.com/api/v3/coins/markets'
    params = {
        'vs_currency': vs_currency,
        'order': 'market_cap_desc',
        'per_page': limit,
        'page': 1,
        'sparkline': False,
        'price_change_percentage': '24h',
        'x_cg_demo_api_key': api_key,
    }
    response = requests.get(url, params=params)
    if response.status_code != 200:
        print(f"Error fetching data: Status code {response.status_code}")
        return []

    data = response.json()

##Extract tickers
    tickers = [coin['symbol'].upper() for coin in data]
    return tickers

# %%
top_coins = fetch_top_coins_tickers(vs_currency='usd', limit=20)
print(top_coins)
# Out:
# ['BTC', 'ETH', 'USDT', 'BNB', 'XRP', 'USDC', 'SOL', 'TRX', 'FIGR_HELOC', 'ZEC', 'HYPE', 'DOGE', 'RAIN', 'USDS', 'XMR', 'WBT', 'LINK', 'LEO', 'ADA', 'XLM']

# %% [markdown]
# ##### yfinance (historical data)

# %%
import yfinance as yf
from datetime import datetime, timedelta


# Specify the symbols for the cryptocurrencies you are interested in
symbols = [f"{coin}-USD" for coin in top_coins]  


df = pd.DataFrame()

# Specify the date range: as far back as yfinance has data, through today.
# (end is exclusive in yfinance, so +1 day to include today's bar.)
start_date = '2011-9-1'
end_date = (datetime.now() + timedelta(days=1)).strftime('%Y-%m-%d')

# Fetch the historical data for each symbol
for symbol in symbols:
    print(f"Fetching data for {symbol}...")
    data = yf.download(symbol, start=start_date, end=end_date, auto_adjust=False)
    if not data.empty:
        # yfinance returns MultiIndex columns (Price, Ticker) even for a
        # single ticker - flatten to just the price field name.
        data.columns = data.columns.get_level_values(0)
        data['Symbol'] = symbol.replace('-USD', '')  
        df = pd.concat([df, data], axis=0)


df.reset_index(inplace=True)
# Out:
# Fetching data for BTC-USD...
# [*********************100%***********************]  1 of 1 completed
# Fetching data for ETH-USD...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Fetching data for USDT-USD...
# Fetching data for BNB-USD...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Fetching data for XRP-USD...
# Fetching data for USDC-USD...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Fetching data for SOL-USD...
# Fetching data for TRX-USD...
# [*********************100%***********************]  1 of 1 completed
# Fetching data for FIGR_HELOC-USD...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: FIGR_HELOC-USD"}}}
# $FIGR_HELOC-USD: possibly delisted; no timezone found
# [*********************100%***********************]  1 of 1 completed
# 1 Failed download:
# ['FIGR_HELOC-USD']: possibly delisted; no timezone found
# Fetching data for ZEC-USD...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Fetching data for HYPE-USD...
# Fetching data for DOGE-USD...
# [*********************100%***********************]  1 of 1 completed
# Fetching data for RAIN-USD...
# [*********************100%***********************]  1 of 1 completed
# Fetching data for USDS-USD...
# [*********************100%***********************]  1 of 1 completed
# Fetching data for XMR-USD...
# [*********************100%***********************]  1 of 1 completed
# Fetching data for WBT-USD...
# [*********************100%***********************]  1 of 1 completed
# Fetching data for LINK-USD...
# [*********************100%***********************]  1 of 1 completed
# Fetching data for LEO-USD...
# [*********************100%***********************]  1 of 1 completed
# Fetching data for ADA-USD...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Fetching data for XLM-USD...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49339 entries, 0 to 49338
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       49339 non-null  datetime64[s]
#  1   Adj Close  49339 non-null  float64
#  2   Close      49339 non-null  float64
#  3   High       49339 non-null  float64
#  4   Low        49339 non-null  float64
#  5   Open       49339 non-null  float64
#  6   Volume     49339 non-null  int64
#  7   Symbol     49339 non-null  str
# dtypes: datetime64[s](1), float64(5), int64(1), str(1)
# memory usage: 3.0 MB

# %% [markdown]
# ### Crypto History Data - data cleansing

# %%
df
# Out:
# Price       Date   Adj Close       Close        High         Low        Open  \
# 0     2014-09-17  457.334015  457.334015  468.174011  452.421997  465.864014
# 1     2014-09-18  424.440002  424.440002  456.859985  413.104004  456.859985
# 2     2014-09-19  394.795990  394.795990  427.834991  384.532013  424.102997
# 3     2014-09-20  408.903992  408.903992  423.295990  389.882996  394.673004
# 4     2014-09-21  398.821014  398.821014  412.425995  393.181000  408.084991
# ...          ...         ...         ...         ...         ...         ...
# 49334 2026-09-10    0.174749    0.174749    0.181191    0.174479    0.181167
# 49335 2026-09-11    0.178238    0.178238    0.184567    0.173464    0.174745
# 49336 2026-09-12    0.180086    0.180086    0.182533    0.178238    0.178238
# 49337 2026-09-13    0.177138    0.177138    0.180851    0.176543    0.180087
# 49338 2026-09-14    0.191181    0.191181    0.196573    0.177008    0.177140
#
# Price     Volume Symbol
# 0       21056800    BTC
# 1       34483200    BTC
# 2       37919700    BTC
# 3       36863600    BTC
# 4       26580100    BTC
# ...          ...    ...
# 49334  150543336    XLM
# 49335  167596709    XLM
# 49336   78151873    XLM
# 49337   81523452    XLM
# 49338  323012250    XLM
#
# [49339 rows x 8 columns]

# %%
df["Date"] = pd.to_datetime(df["Date"])
df = df.rename(columns={'Volume': 'Volume($)'})

# %%
df.isnull().sum()
# Out:
# Price
# Date         0
# Adj Close    0
# Close        0
# High         0
# Low          0
# Open         0
# Volume($)    0
# Symbol       0
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])

# Calculate daily returns for each cryptocurrency
df['Daily Return'] = df.groupby('Symbol')['Close'].pct_change()

# %%
df.isnull().sum()
# Out:
# Price
# Date             0
# Adj Close        0
# Close            0
# High             0
# Low              0
# Open             0
# Volume($)        0
# Symbol           0
# Daily Return    19
# dtype: int64

# %%
df_filtered_date = df[df['Date'] == '2024-01-01']

df_sorted_by_close = df_filtered_date.sort_values(by='Close', ascending=False)

df_sorted_by_close[['Symbol', 'Close']]
# Out:
# Price Symbol         Close
# 3393     BTC  44167.332031
# 6625     ETH   2352.327881
# 13089    BNB    314.408295
# 34500    XMR    169.605835
# 21569    SOL    109.508682
# 28033    ZEC     27.826603
# 39213   LINK     15.535809
# 35981    WBT      5.795457
# 41887    LEO      3.972346
# 9857    USDT      1.000368
# 19220   USDC      1.000131
# 16321    XRP      0.630082
# 45119    ADA      0.623110
# 48351    XLM      0.131905
# 24801    TRX      0.107812
# 31266   DOGE      0.092024

# %%
rows_with_null = df[df.isnull().any(axis=1)]

rows_with_null
# Out:
# Price       Date   Adj Close       Close        High         Low        Open  \
# 0     2014-09-17  457.334015  457.334015  468.174011  452.421997  465.864014
# 4381  2017-11-09  320.884003  320.884003  329.451996  307.056000  308.644989
# 7613  2017-11-09    1.008180    1.008180    1.013270    0.996515    1.010870
# 10845 2017-11-09    1.990770    1.990770    2.174230    1.893940    2.053140
# 14077 2017-11-09    0.217488    0.217488    0.221791    0.214866    0.217911
# 17309 2018-10-08    1.002210    1.002210    1.007680    1.001900    1.004100
# 20208 2020-04-10    0.951054    0.951054    1.313487    0.694187    0.832005
# 22557 2017-11-09    0.002344    0.002344    0.002438    0.002285    0.002304
# 25789 2017-11-09  261.998993  261.998993  270.177002  244.143005  250.552994
# 29021 2024-08-27    0.000005    0.000005    0.000005    0.000005    0.000005
# 29022 2017-11-09    0.001415    0.001415    0.001415    0.001181    0.001207
# 32254 2026-04-29    0.000016    0.000016    0.000016    0.000016    0.000016
# 32255 2023-04-11    1.025020    1.025020    1.025020    0.063754    0.063754
# 32256 2017-11-09  120.779999  120.779999  123.404999  112.219002  112.531998
# 35488 2022-08-26    4.500193    4.500193    5.590310    4.443162    5.575397
# 36969 2017-11-09    0.223969    0.223969    0.248233    0.195411    0.216713
# 40201 2019-05-21    1.037136    1.037136    1.066795    1.034780    1.052109
# 42875 2017-11-09    0.032053    0.032053    0.035060    0.025006    0.025160
# 46107 2017-11-09    0.039946    0.039946    0.040380    0.033744    0.033792
#
# Price  Volume($) Symbol  Daily Return
# 0       21056800    BTC           NaN
# 4381   893249984    ETH           NaN
# 7613   358188000   USDT           NaN
# 10845   19192200    BNB           NaN
# 14077  147916992    XRP           NaN
# 17309     382900   USDC           NaN
# 20208   87364276    SOL           NaN
# 22557    2924350    TRX           NaN
# 25789   86573400    ZEC           NaN
# 29021       2670   HYPE           NaN
# 29022    6259550   DOGE           NaN
# 32254         49   RAIN           NaN
# 32255       1032   USDS           NaN
# 32256   86864600    XMR           NaN
# 35488    4101325    WBT           NaN
# 36969    3347920   LINK           NaN
# 40201    2723774    LEO           NaN
# 42875   18716200    ADA           NaN
# 46107   32813200    XLM           NaN

# %%
df['Symbol'].unique()
# Out:
# <StringArray>
# [ 'BTC',  'ETH', 'USDT',  'BNB',  'XRP', 'USDC',  'SOL',  'TRX',  'ZEC',
#  'HYPE', 'DOGE', 'RAIN', 'USDS',  'XMR',  'WBT', 'LINK',  'LEO',  'ADA',
#   'XLM']
# Length: 19, dtype: str

# %%
exclude_symbols = ['SHIB', 'ICP','STETH','WBTC','USDC','UNI']

# Filter 
df = df[~df['Symbol'].isin(exclude_symbols)]

# %%
df['Symbol'].unique()
# Out:
# <StringArray>
# [ 'BTC',  'ETH', 'USDT',  'BNB',  'XRP',  'SOL',  'TRX',  'ZEC', 'HYPE',
#  'DOGE', 'RAIN', 'USDS',  'XMR',  'WBT', 'LINK',  'LEO',  'ADA',  'XLM']
# Length: 18, dtype: str

# %%
df.head()
# Out:
# Price       Date   Adj Close       Close        High         Low        Open  \
# 0     2014-09-17  457.334015  457.334015  468.174011  452.421997  465.864014
# 1     2014-09-18  424.440002  424.440002  456.859985  413.104004  456.859985
# 2     2014-09-19  394.795990  394.795990  427.834991  384.532013  424.102997
# 3     2014-09-20  408.903992  408.903992  423.295990  389.882996  394.673004
# 4     2014-09-21  398.821014  398.821014  412.425995  393.181000  408.084991
#
# Price  Volume($) Symbol  Daily Return
# 0       21056800    BTC           NaN
# 1       34483200    BTC     -0.071926
# 2       37919700    BTC     -0.069843
# 3       36863600    BTC      0.035735
# 4       26580100    BTC     -0.024659

# %%
save_df(df, 'raw_prices')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 46440 entries, 0 to 49338
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          46440 non-null  datetime64[s]
#  1   Adj Close     46440 non-null  float64
#  2   Close         46440 non-null  float64
#  3   High          46440 non-null  float64
#  4   Low           46440 non-null  float64
#  5   Open          46440 non-null  float64
#  6   Volume($)     46440 non-null  int64
#  7   Symbol        46440 non-null  str
#  8   Daily Return  46422 non-null  float64
# dtypes: datetime64[s](1), float64(6), int64(1), str(1)
# memory usage: 3.5 MB
